# %% [markdown]
# <a href="https://colab.research.google.com/github/sanjeevafk/glasseye/blob/main/scripts/train_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🚀 GlassEye: YOLOv8 640px GPU Training & Auto-Deploy
#
# This notebook downloads the packaged **640px BFDD + CUBIT dataset** from Hugging Face (`sanjeevafk/glasseye-bfdd-cubit-640`), fine-tunes **YOLOv8n at 640px native resolution** on a free T4 GPU (~8 minutes), and automatically uploads the trained `best.pt` checkpoint to Hugging Face Model Hub.
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/sanjeevafk/glasseye/blob/main/scripts/train_colab.ipynb)

# %%
# 1. Install Ultralytics and Hugging Face Hub
# !pip install -q ultralytics huggingface_hub
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.5/45.5 kB 4.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 70.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.9/63.9 kB 7.9 MB/s eta 0:00:00

# %%
# 2. Clone GlassEye and Run GPU Training with Auto-Upload
import getpass
import os

if "HF_TOKEN" not in os.environ:
    token = getpass.getpass("Enter your Hugging Face Token (hf_...): ")
    os.environ["HF_TOKEN"] = token.strip()

# !git clone https://github.com/sanjeevafk/glasseye.git /content/glasseye
# %cd /content/glasseye
# !python scripts/train_colab.py
