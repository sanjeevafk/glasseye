# %% [markdown]
# # 🚀 GlassEye: YOLOv8 640px 3-Way GPU Training & Auto-Deploy
#
# This notebook downloads the packaged **640px 3-Way Unified Dataset (BFDD + CUBIT + UAV2K)** from Hugging Face (`sanjeevafk/glasseye-bfdd-cubit-uav2k-640`), fine-tunes **YOLOv8n at 640px native resolution** on a free T4 GPU (~12 minutes), and automatically uploads the trained `best.pt` checkpoint to Hugging Face Model Hub.
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/sanjeevafk/glasseye/blob/main/scripts/train_colab.ipynb)

# %%
# 1. Install Ultralytics and Hugging Face Hub
# !pip install -q ultralytics huggingface_hub

# %%
# 2. Clone/Pull GlassEye and Run 3-Way GPU Training with Auto-Upload
import getpass
import os

if "HF_TOKEN" not in os.environ:
    token = getpass.getpass("Enter your Hugging Face Token (hf_...): ")
    os.environ["HF_TOKEN"] = token.strip()

# %cd /content
# !rm -rf /content/glasseye
# !git clone https://github.com/sanjeevafk/glasseye.git /content/glasseye
# %cd /content/glasseye
# !python scripts/train_colab.py
